# %% [markdown]
# # Data Science and Business Analytics Intern
# ---
# GRIP at The Sparks Foundation
#
# ---
# Intern Name : Siddhi Sanjay Lad
#
# ---
# Task 6 : Prediction using Decision Tree algorithm
#
# ---
# *To create a Decision Tree Classifier and visualize it graphically. The purpose is if we feed any new data to this classifier, it should be able to predict the right class accordingly.*

# %% [markdown]
# ---
#
# ### Step 1 - To import the required libraries.
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# ---
#
# ### Step 2 - To load and read the dataset.
#
# ---

# %%
data = pd.read_csv('./Iris.csv', index_col = 0)
data.head()

# %%
X, y = data.iloc[ : , : -1], data.iloc[ : , -1]

# %% [markdown]
# ---
#
# ### Step 3 - Splitting the data.
#
# ---

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state = 0, shuffle = True, test_size = 0.2)
X_train.head()

# %% [markdown]
# ---
#
# ### Step 4 - To generate predicitions for the test data.
#
# ---

# %%
treeModel = DecisionTreeClassifier(max_depth = 3)   
treeModel.fit(X_train, y_train)
y_preds = treeModel.predict(X_val)

# %% [markdown]
# ---
#
# ### Step 5 - To visualize the decision tree.
#
# ---

# %%
plt.figure(figsize = (15, 15))
plot_tree(treeModel,
         feature_names=X.columns,
         class_names=y.unique(),
         filled = True);

# %% [markdown]
# ---
#
# ### Step 4 - To calculate the accuracy of the model.
#
# ---

# %%
print(classification_report(y_val, y_preds))

# %% [markdown]
# ---
# ### Accuracy of the model: 97 %
#
# ---
# ## Conclusion
#
# ### I could successfully carry-out the task of Prediction using Decision Tree Algorithm.
#
# ---
#
# ## Thank You
# ---
